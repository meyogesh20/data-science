# %% [markdown]
# # Python Collections -
# * There are four collection data types in the Python programming language:
#
# 1. <code>List</code> is a collection which is ordered and changeable. Allows duplicate members.
# 2. <code>Tuple</code> is a collection which is ordered and unchangeable. Allows duplicate members.
# 3. <code>Set</code> is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# 4. <code>Dictionary</code> is a collection which is ordered** and changeable. No duplicate members.<br>
#
#     * <code>Set</code> items are unchangeable, but you can remove and/or add items whenever you like.<br>
#     * As of Python version 3.7, dictionaries are ordered. In Python 3.6 and earlier, dictionaries are unordered.

# %% [markdown]
# # List
# 1. List items are ordered, changeable, and allow duplicate values.
#    - The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.
#    - Allow duplicate : Since lists are indexed, lists can have items with the same value
# 3. List can hold a variety of object types. A list can contain different data types:
# 4. Lists are used to store multiple items in a single variable.
# 5. They use [] brackets and cammas to separete objects in the list.
#    #### [1,2,3,4,5]
# 6. Lists support indexing and slicing. Lists can be nested and also have a variety of useful methods that can be called off of them.
# 7. It is also possible to use the list() constructor when creating a new list.
#    - thislist = list(("apple", "banana", "cherry")) # note the double round-brackets
#      <code>print(thislist)</code>

# %%
my_list = [1,2,3]
my_list
# Out:
# [1, 2, 3]

# %%
my_list1 = ['a','abc',10,3.14]
my_list1
# Out:
# ['a', 'abc', 10, 3.14]

# %%
len(my_list)
# Out:
# 3

# %%
# Retrieve list element
print(my_list[0])
print(my_list[1])
# Out:
# 1
# 2

# %% [markdown]
# ### List concatenation using +
# * Just link string concatenation

# %%
my_list + my_list1
# Out:
# [1, 2, 3, 'a', 'abc', 10, 3.14]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list1
# Out:
# ['a', 'abc', 10, 3.14]

# %%
new_list = my_list + my_list1
new_list
# Out:
# [1, 2, 3, 'a', 'abc', 10, 3.14]

# %% [markdown]
# ### List is mutable - We can change the element of the list

# %%
# Change list element
new_list[0] = 'Changed'
new_list
# Out:
# ['Changed', 2, 3, 'a', 'abc', 10, 3.14]

# %%
# Append element to the list
new_list.append('xyz')
new_list.append(100)

# %%
new_list
# Out:
# [2, 3, 'a', 'abc', 10, 3.14, 'xyz']

# %%
new_list.insert(5,8) #insert 8 at 5th index
new_list
# Out:
# [2, 3, 'a', 'abc', 10, 8, 8, 3.14, 'xyz']

# %%
new_list.remove('xyz') #remove the item by specifying its value
new_list
# Out:
# [2, 3, 'a', 'abc', 10, 8, 8, 3.14]

# %%
# Remove the item from specific index
del new_list[5]
new_list
# Out:
# [2, 3, 'a', 'abc', 10, 8, 3.14]

# %%
# Delete list element
new_list.pop() # By default last element will be popped up
new_list
# Out:
# ['Changed', 2, 3, 'a', 'abc', 10, 3.14, 'xyz']

# %%
# Delete element at the index position
new_list.pop(0) # element at 0 index will be popped up
new_list
# Out:
# [2, 3, 'a', 'abc', 10, 3.14, 'xyz']

# %%
new_list.clear() #Clear the list, emptying the list
new_list
# Out:
# []

# %% [markdown]
# #### Slicing and indexing is possible in list just like string
# ### List - Sort and Reverse

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Note:</b> Sort and Reverse functions returns Nothing. Sorting and Reverse happens in place
# </div>

# %%
char_list = ['x', 'f','w','b','a','s','o']
num_list = [96, 65, 23, 76, 11, 5]
num_list
# Out:
# [96, 65, 23, 76, 11, 5]

# %%
# sort function returns nothing
char_list.sort(reverse=True)
char_list
# Out:
# ['x', 'w', 's', 'o', 'f', 'b', 'a']

# %%
type(sorted_list)
# Out:
# NoneType

# %%
sorted_list = char_list
sorted_list
print(char_list)
print(num_list)
# Out:
# ['a', 'b', 'f', 'o', 's', 'w', 'x']
# [96, 65, 23, 76, 11, 5]

# %%
rev_num = num_list
print(rev_num)
# Out:
# [96, 65, 23, 76, 11, 5]

# %%
rev_num[0] = 1
print(num_list)
# Out:
# [1, 65, 23, 76, 11, 5]
